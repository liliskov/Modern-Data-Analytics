# %%
def netCDF4_to_DF(nc4_file_path,nc4_key): #Condition- function starts from year 1980, nc4_file_path -> str ,nc4_key -> str
    try:
        import netCDF4
        from netCDF4 import Dataset
        import pandas as pd
        import numpy as np
    except:
        print("Error - Required Libraries not installed")
        break
    try:
        ds = Dataset(nc4_file_path)
    except:
        print('Error - Dataset not able to find the file')
        break
    if type(yearN) is not int:
        print('Error - Check input for year')
        break 
    else if yearN < 0
        print("Error- enter a positive number for year")
        break
    if type(nc4_key) is not str:
        print('Error - Check input for key type')
        break
    key = ds[nc4_key][:]
    if not key:
      print("List is empty")
      break
    lat = ds['lat'][:]
    lon = ds['lon'][:]
    
    year = 1980
    count = 0
    
    for i in range(80,116):
        data = key[i,:,:]
        if i == 80:
            data_pd = pd.DataFrame(data = data)
            lat = ds['lat'][:]
            data_pd.index =  lat
            lon = ds['lon'][:]
            data_pd.columns = lon
            data_pd = pd.melt(data_pd, ignore_index = False, var_name='lon', value_name='1980')
        else:
            data_I = pd.DataFrame(data = data)
            data_I.index =  lat
            year = year+1
            data_I = pd.melt(data_I,ignore_index = False, value_name= str(year))
            data_pd[str(year)] = data_I.loc[:,str(year)]
            count = count +1
            print(count)
    return data_pd

def netCDF4_to_DF_Year(nc4_file_path,nc4_key,yearN):#Condition- function starts from user given year, nc4_file_path -> str ,nc4_key -> str, year -> int
    try:
        import netCDF4
        from netCDF4 import Dataset
        import pandas as pd
        import numpy as np
    except:
        print("Error - Required Libraries not installed")
        break
    try:
        ds = Dataset(nc4_file_path)
    except:
        print('Error - Dataset not able to find the file')
        break
    if type(yearN) is not int:
        print('Error - Check input for year')
        break 
    else if yearN < 0
        print("Error- enter a positive number for year")
        break
    
    if type(nc4_key) is not str:
        print('Error - Check input for key type')
        break
    ##############################use the following code below to identify the number of year/month, its the first variable 
    #import h5py
    #f = h5py.File('watergap_22d_WFDEI-GPCC_histsoc_pdomww_yearly_1901_2016.nc4', 'r')
    #f2 = f.keys()
    #f['pdomww'].shape
    
    key = ds[nc4_key][:]
    if not key:
      print("List is empty")
      break
    lat = ds['lat'][:]
    lon = ds['lon'][:]
    
    year = 1980
    count = 0
    
    for i in range(80,116):
        data = key[i,:,:]
        if i == 80:
            data_pd = pd.DataFrame(data = data)
            lat = ds['lat'][:]
            data_pd.index =  lat
            lon = ds['lon'][:]
            data_pd.columns = lon
            data_pd = pd.melt(data_pd, ignore_index = False, var_name='lon', value_name='1980')
        else:
            data_I = pd.DataFrame(data = data)
            data_I.index =  lat
            year = year+1
            data_I = pd.melt(data_I,ignore_index = False, value_name= str(year))
            data_pd[str(year)] = data_I.loc[:,str(year)]
            count = count +1
            print(count)
    return data_pd
